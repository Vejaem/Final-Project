# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sb

# %%
# Read the csv file into a pandas DataFrame

ncaa = pd.read_csv('cbb.csv')
ncaa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1757 entries, 0 to 1756
# Data columns (total 24 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   TEAM        1757 non-null   object
#  1   CONF        1757 non-null   object
#  2   G           1757 non-null   int64
#  3   W           1757 non-null   int64
#  4   ADJOE       1757 non-null   float64
#  5   ADJDE       1757 non-null   float64
#  6   BARTHAG     1757 non-null   float64
#  7   EFG_O       1757 non-null   float64
#  8   EFG_D       1757 non-null   float64
#  9   TOR         1757 non-null   float64
#  10  TORD        1757 non-null   float64
#  11  ORB         1757 non-null   float64
#  12  DRB         1757 non-null   float64
#  13  FTR         1757 non-null   float64
#  14  FTRD        1757 non-null   float64
#  15  TWO_P_O     1757 non-null   float64
#  16  TWO_P_D     1757 non-null   float64
#  17  THREE_P_O   1757 non-null   float64
#  18  THREE_P_D   1757 non-null   float64
#  19  ADJ_T       1757 non-null   float64
#  20  WAB         1757 non-null   float64
#  21  POSTSEASON  340 non-null    object
#  22  SEED        340 non-null    float64
#  23  YEAR        1757 non-null   int64
# dtypes: float64(18), int64(3), object(3)
# memory usage: 329.6+ KB

# %%
# ncaa_2019_df = ncaa[(ncaa.YEAR == 2019)]
# ncaa_2019_df.dropna
ncaa.sort_values(by=['TEAM'])
# Out:
#                    TEAM  CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D  \
# 1260  Abilene Christian  Slnd  25  13   97.5  107.5   0.2450   52.5   52.8
# 1236  Abilene Christian  Slnd  28   7   90.6  111.3   0.0854   47.3   55.3
# 1272  Abilene Christian  Slnd  28  16   96.5  106.6   0.2423   50.4   51.4
# 1248  Abilene Christian  Slnd  27   9   96.3  111.8   0.1529   50.5   54.6
# 1682  Abilene Christian  Slnd  30  27  100.9  100.7   0.5064   51.9   49.8
# ...                 ...   ...  ..  ..    ...    ...      ...    ...    ...
# 614      Youngstown St.  Horz  30   8  101.1  114.5   0.1931   47.6   58.7
# 623      Youngstown St.  Horz  30  12  103.8  111.0   0.3167   49.6   53.6
# 596      Youngstown St.  Horz  30   9  101.6  113.3   0.2215   49.0   53.6
# 605      Youngstown St.  Horz  32  13  101.0  112.8   0.2204   49.1   53.0
# 587      Youngstown St.  Horz  29   8  103.4  112.0   0.2850   50.1   53.6
#
#        TOR  ...  FTRD  TWO_P_O  TWO_P_D  THREE_P_O  THREE_P_D  ADJ_T   WAB  \
# 1260  21.0  ...  44.3     50.7     52.1       37.1       36.1   67.1 -12.5
# 1236  19.8  ...  44.7     42.0     55.2       37.8       37.0   64.0 -16.8
# 1272  20.3  ...  43.2     51.9     52.3       31.8       33.2   69.8 -11.3
# 1248  19.2  ...  46.5     48.4     54.2       36.3       36.9   68.4 -14.4
# 1682  17.3  ...  38.3     49.5     49.8       37.7       33.3   67.1  -2.6
# ...    ...  ...   ...      ...      ...        ...        ...    ...   ...
# 614   19.4  ...  39.8     46.5     57.4       33.2       40.8   72.4 -17.9
# 623   18.5  ...  38.5     48.5     55.0       34.1       34.2   68.7 -14.0
# 596   15.6  ...  32.5     45.5     54.5       37.0       34.6   73.2 -14.0
# 605   16.0  ...  29.1     49.0     53.5       32.8       34.6   73.1 -15.4
# 587   17.2  ...  36.8     48.5     51.7       35.6       37.9   67.6 -14.7
#
#       POSTSEASON  SEED  YEAR
# 1260         NaN   NaN  2017
# 1236         NaN   NaN  2015
# 1272         NaN   NaN  2018
# 1248         NaN   NaN  2016
# 1682         R64  15.0  2019
# ...          ...   ...   ...
# 614          NaN   NaN  2018
# 623          NaN   NaN  2019
# 596          NaN   NaN  2016
# 605          NaN   NaN  2017
# 587          NaN   NaN  2015
#
# [1757 rows x 24 columns]

# %%
# # Use Pandas get_dummies to convert categorical data

# ncaa = pd.get_dummies(ncaa)
# ncaa

# %%
# Drop extra dummy columns

seeded_teams_df = ncaa.drop(columns=['POSTSEASON','SEED'], axis=1)
seeded_teams_df
# Out:
#                 TEAM CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  \
# 0     North Carolina  ACC  40  33  123.3   94.9   0.9531   52.6   48.1  15.4
# 1          Wisconsin  B10  40  36  129.1   93.6   0.9758   54.8   47.7  12.4
# 2           Michigan  B10  40  33  114.4   90.4   0.9375   53.9   47.7  14.0
# 3         Texas Tech  B12  38  31  115.2   85.2   0.9696   53.5   43.0  17.7
# 4            Gonzaga  WCC  39  37  117.8   86.3   0.9728   56.6   41.1  16.2
# ...              ...  ...  ..  ..    ...    ...      ...    ...    ...   ...
# 1752       Texas A&M  SEC  35  22  111.2   94.7   0.8640   51.4   46.9  19.2
# 1753             LSU  SEC  35  28  117.9   96.6   0.9081   51.2   49.9  17.9
# 1754       Tennessee  SEC  36  31  122.8   95.2   0.9488   55.3   48.1  15.8
# 1755         Gonzaga  WCC  35  27  117.4   94.5   0.9238   55.2   44.8  17.1
# 1756         Gonzaga  WCC  37  32  117.2   94.9   0.9192   57.0   47.1  16.1
#
#       ...   DRB   FTR  FTRD  TWO_P_O  TWO_P_D  THREE_P_O  THREE_P_D  ADJ_T  \
# 0     ...  30.0  32.3  30.4     53.9     44.6       32.7       36.2   71.7
# 1     ...  23.7  36.2  22.4     54.8     44.7       36.5       37.5   59.3
# 2     ...  24.9  30.7  30.0     54.7     46.8       35.2       33.2   65.9
# 3     ...  28.7  32.9  36.6     52.8     41.9       36.5       29.7   67.5
# 4     ...  26.2  39.0  26.9     56.3     40.0       38.2       29.0   71.5
# ...   ...   ...   ...   ...      ...      ...        ...        ...    ...
# 1752  ...  27.3  32.0  27.6     52.5     45.7       32.9       32.6   70.3
# 1753  ...  30.8  37.1  33.1     52.9     49.4       31.9       33.7   71.2
# 1754  ...  30.2  33.3  34.9     55.4     44.7       36.7       35.4   68.8
# 1755  ...  26.0  34.4  28.1     54.3     44.4       37.8       30.3   68.2
# 1756  ...  23.1  32.1  29.1     58.2     44.1       36.8       35.0   70.5
#
#        WAB  YEAR
# 0      8.6  2016
# 1     11.3  2015
# 2      6.9  2018
# 3      7.0  2019
# 4      7.7  2017
# ...    ...   ...
# 1752   1.9  2018
# 1753   7.3  2019
# 1754   9.9  2019
# 1755   2.1  2016
# 1756   4.9  2018
#
# [1757 rows x 22 columns]

# %%
# renmae columns

ncaa.rename({'ADJOE':'Offensive Efficency',
            'ADJDE':'Defensive Efficency',
            'BARTHAG':'Power Rating',
            'TWO_P_O':'Two Pointer Percentage', 
            'TWO_P_D':'Two Point Percentage Allowed',
            'THREE_P_O':'Three Pointer Percentage',
            'THREE_P_D':'Three Point Percentage Allowed',
            'ADJ_T':'Posessions Per Game'},
            axis=1, inplace=True)
ncaa
# Out:
#                 TEAM CONF   G   W  Offensive Efficency  Defensive Efficency  \
# 0     North Carolina  ACC  40  33                123.3                 94.9
# 1          Wisconsin  B10  40  36                129.1                 93.6
# 2           Michigan  B10  40  33                114.4                 90.4
# 3         Texas Tech  B12  38  31                115.2                 85.2
# 4            Gonzaga  WCC  39  37                117.8                 86.3
# ...              ...  ...  ..  ..                  ...                  ...
# 1752       Texas A&M  SEC  35  22                111.2                 94.7
# 1753             LSU  SEC  35  28                117.9                 96.6
# 1754       Tennessee  SEC  36  31                122.8                 95.2
# 1755         Gonzaga  WCC  35  27                117.4                 94.5
# 1756         Gonzaga  WCC  37  32                117.2                 94.9
#
#       Power Rating  EFG_O  EFG_D   TOR  ...  FTRD  Two Pointer Percentage  \
# 0           0.9531   52.6   48.1  15.4  ...  30.4                    53.9
# 1           0.9758   54.8   47.7  12.4  ...  22.4                    54.8
# 2           0.9375   53.9   47.7  14.0  ...  30.0                    54.7
# 3           0.9696   53.5   43.0  17.7  ...  36.6                    52.8
# 4           0.9728   56.6   41.1  16.2  ...  26.9                    56.3
# ...            ...    ...    ...   ...  ...   ...                     ...
# 1752        0.8640   51.4   46.9  19.2  ...  27.6                    52.5
# 1753        0.9081   51.2   49.9  17.9  ...  33.1                    52.9
# 1754        0.9488   55.3   48.1  15.8  ...  34.9                    55.4
# 1755        0.9238   55.2   44.8  17.1  ...  28.1                    54.3
# 1756        0.9192   57.0   47.1  16.1  ...  29.1                    58.2
#
#       Two Point Percentage Allowed  Three Pointer Percentage  \
# 0                             44.6                      32.7
# 1                             44.7                      36.5
# 2                             46.8                      35.2
# 3                             41.9                      36.5
# 4                             40.0                      38.2
# ...                            ...                       ...
# 1752                          45.7                      32.9
# 1753                          49.4                      31.9
# 1754                          44.7                      36.7
# 1755                          44.4                      37.8
# 1756                          44.1                      36.8
#
#       Three Point Percentage Allowed  Posessions Per Game   WAB  POSTSEASON  \
# 0                               36.2                 71.7   8.6         2ND
# 1                               37.5                 59.3  11.3         2ND
# 2                               33.2                 65.9   6.9         2ND
# 3                               29.7                 67.5   7.0         2ND
# 4                               29.0                 71.5   7.7         2ND
# ...                              ...                  ...   ...         ...
# 1752                            32.6                 70.3   1.9         S16
# 1753                            33.7                 71.2   7.3         S16
# 1754                            35.4                 68.8   9.9         S16
# 1755                            30.3                 68.2   2.1         S16
# 1756                            35.0                 70.5   4.9         S16
#
#       SEED  YEAR
# 0      1.0  2016
# 1      1.0  2015
# 2      3.0  2018
# 3      3.0  2019
# 4      1.0  2017
# ...    ...   ...
# 1752   7.0  2018
# 1753   3.0  2019
# 1754   2.0  2019
# 1755  11.0  2016
# 1756   4.0  2018
#
# [1757 rows x 24 columns]

# %%
ncaa['Win_Percentage']=ncaa['W'] / ncaa['G']

# (seeded_teams_df['Power Rating']>=0.9555,1,0 )
ncaa
# Out:
#                 TEAM CONF   G   W  Offensive Efficency  Defensive Efficency  \
# 0     North Carolina  ACC  40  33                123.3                 94.9
# 1          Wisconsin  B10  40  36                129.1                 93.6
# 2           Michigan  B10  40  33                114.4                 90.4
# 3         Texas Tech  B12  38  31                115.2                 85.2
# 4            Gonzaga  WCC  39  37                117.8                 86.3
# ...              ...  ...  ..  ..                  ...                  ...
# 1752       Texas A&M  SEC  35  22                111.2                 94.7
# 1753             LSU  SEC  35  28                117.9                 96.6
# 1754       Tennessee  SEC  36  31                122.8                 95.2
# 1755         Gonzaga  WCC  35  27                117.4                 94.5
# 1756         Gonzaga  WCC  37  32                117.2                 94.9
#
#       Power Rating  EFG_O  EFG_D   TOR  ...  Two Pointer Percentage  \
# 0           0.9531   52.6   48.1  15.4  ...                    53.9
# 1           0.9758   54.8   47.7  12.4  ...                    54.8
# 2           0.9375   53.9   47.7  14.0  ...                    54.7
# 3           0.9696   53.5   43.0  17.7  ...                    52.8
# 4           0.9728   56.6   41.1  16.2  ...                    56.3
# ...            ...    ...    ...   ...  ...                     ...
# 1752        0.8640   51.4   46.9  19.2  ...                    52.5
# 1753        0.9081   51.2   49.9  17.9  ...                    52.9
# 1754        0.9488   55.3   48.1  15.8  ...                    55.4
# 1755        0.9238   55.2   44.8  17.1  ...                    54.3
# 1756        0.9192   57.0   47.1  16.1  ...                    58.2
#
#       Two Point Percentage Allowed  Three Pointer Percentage  \
# 0                             44.6                      32.7
# 1                             44.7                      36.5
# 2                             46.8                      35.2
# 3                             41.9                      36.5
# 4                             40.0                      38.2
# ...                            ...                       ...
# 1752                          45.7                      32.9
# 1753                          49.4                      31.9
# 1754                          44.7                      36.7
# 1755                          44.4                      37.8
# 1756                          44.1                      36.8
#
#       Three Point Percentage Allowed  Posessions Per Game   WAB  POSTSEASON  \
# 0                               36.2                 71.7   8.6         2ND
# 1                               37.5                 59.3  11.3         2ND
# 2                               33.2                 65.9   6.9         2ND
# 3                               29.7                 67.5   7.0         2ND
# 4                               29.0                 71.5   7.7         2ND
# ...                              ...                  ...   ...         ...
# 1752                            32.6                 70.3   1.9         S16
# 1753                            33.7                 71.2   7.3         S16
# 1754                            35.4                 68.8   9.9         S16
# 1755                            30.3                 68.2   2.1         S16
# 1756                            35.0                 70.5   4.9         S16
#
#       SEED  YEAR  Win_Percentage
# 0      1.0  2016        0.825000
# 1      1.0  2015        0.900000
# 2      3.0  2018        0.825000
# 3      3.0  2019        0.815789
# 4      1.0  2017        0.948718
# ...    ...   ...             ...
# 1752   7.0  2018        0.628571
# 1753   3.0  2019        0.800000
# 1754   2.0  2019        0.861111
# 1755  11.0  2016        0.771429
# 1756   4.0  2018        0.864865
#
# [1757 rows x 25 columns]

# %%
###############################################################

# %%
ncaa['Win_Percentage'].describe()
# Out:
# count    1757.000000
# mean        0.515542
# std         0.178418
# min         0.000000
# 25%         0.387097
# 50%         0.518519
# 75%         0.645161
# max         0.974359
# Name: Win_Percentage, dtype: float64

# %%
len(ncaa['Win_Percentage'].unique())
# Out:
# 240

# %%
len(ncaa['W'].unique())
# Out:
# 39

# %%
len(ncaa) / 240
# Out:
# 7.320833333333334

# %%
np.where (ncaa['Win_Percentage']>=0.518519,1,0 )
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
ncaa['Target'] = np.where (ncaa['Win_Percentage']>=0.518519,1,0 )

# %%
ncaa
# Out:
#                 TEAM CONF   G   W  Offensive Efficency  Defensive Efficency  \
# 0     North Carolina  ACC  40  33                123.3                 94.9
# 1          Wisconsin  B10  40  36                129.1                 93.6
# 2           Michigan  B10  40  33                114.4                 90.4
# 3         Texas Tech  B12  38  31                115.2                 85.2
# 4            Gonzaga  WCC  39  37                117.8                 86.3
# ...              ...  ...  ..  ..                  ...                  ...
# 1752       Texas A&M  SEC  35  22                111.2                 94.7
# 1753             LSU  SEC  35  28                117.9                 96.6
# 1754       Tennessee  SEC  36  31                122.8                 95.2
# 1755         Gonzaga  WCC  35  27                117.4                 94.5
# 1756         Gonzaga  WCC  37  32                117.2                 94.9
#
#       Power Rating  EFG_O  EFG_D   TOR  ...  Two Point Percentage Allowed  \
# 0           0.9531   52.6   48.1  15.4  ...                          44.6
# 1           0.9758   54.8   47.7  12.4  ...                          44.7
# 2           0.9375   53.9   47.7  14.0  ...                          46.8
# 3           0.9696   53.5   43.0  17.7  ...                          41.9
# 4           0.9728   56.6   41.1  16.2  ...                          40.0
# ...            ...    ...    ...   ...  ...                           ...
# 1752        0.8640   51.4   46.9  19.2  ...                          45.7
# 1753        0.9081   51.2   49.9  17.9  ...                          49.4
# 1754        0.9488   55.3   48.1  15.8  ...                          44.7
# 1755        0.9238   55.2   44.8  17.1  ...                          44.4
# 1756        0.9192   57.0   47.1  16.1  ...                          44.1
#
#       Three Pointer Percentage  Three Point Percentage Allowed  \
# 0                         32.7                            36.2
# 1                         36.5                            37.5
# 2                         35.2                            33.2
# 3                         36.5                            29.7
# 4                         38.2                            29.0
# ...                        ...                             ...
# 1752                      32.9                            32.6
# 1753                      31.9                            33.7
# 1754                      36.7                            35.4
# 1755                      37.8                            30.3
# 1756                      36.8                            35.0
#
#       Posessions Per Game   WAB  POSTSEASON  SEED  YEAR  Win_Percentage  \
# 0                    71.7   8.6         2ND   1.0  2016        0.825000
# 1                    59.3  11.3         2ND   1.0  2015        0.900000
# 2                    65.9   6.9         2ND   3.0  2018        0.825000
# 3                    67.5   7.0         2ND   3.0  2019        0.815789
# 4                    71.5   7.7         2ND   1.0  2017        0.948718
# ...                   ...   ...         ...   ...   ...             ...
# 1752                 70.3   1.9         S16   7.0  2018        0.628571
# 1753                 71.2   7.3         S16   3.0  2019        0.800000
# 1754                 68.8   9.9         S16   2.0  2019        0.861111
# 1755                 68.2   2.1         S16  11.0  2016        0.771429
# 1756                 70.5   4.9         S16   4.0  2018        0.864865
#
#       Target
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 1752       1
# 1753       1
# 1754       1
# 1755       1
# 1756       1
#
# [1757 rows x 26 columns]

# %%
sb.countplot(x='Target', data = ncaa)

# %%
plt.figure(figsize = (15,10))
sb.heatmap(ncaa.corr(),annot=True,fmt='.3f')

# %%
ncaa.drop('Target', axis = 1).corrwith(ncaa['Target']).abs().sort_values(ascending=True).plot(kind='barh')

# %%
tournament.dtypes
# Out:
# Offensive Efficency               float64
# Defensive Efficency               float64
# Power Rating                      float64
# EFG_O                             float64
# EFG_D                             float64
# TOR                               float64
# TORD                              float64
# ORB                               float64
# DRB                               float64
# FTR                               float64
# FTRD                              float64
# Two Pointer Percentage            float64
# Two Point Percentage Allowed      float64
# Three Pointer Percentage          float64
# Three Point Percentage Allowed    float64
# Posessions Per Game               float64
# WAB                               float64
# YEAR                                int64
# Target                              int32
# dtype: object

# %%
tournament = ncaa.drop(columns=['Win_Percentage','W', 'G', 'TEAM', 'CONF', 'POSTSEASON', 'SEED'], axis=1)
tournament
# Out:
#       Offensive Efficency  Defensive Efficency  Power Rating  EFG_O  EFG_D  \
# 0                   123.3                 94.9        0.9531   52.6   48.1
# 1                   129.1                 93.6        0.9758   54.8   47.7
# 2                   114.4                 90.4        0.9375   53.9   47.7
# 3                   115.2                 85.2        0.9696   53.5   43.0
# 4                   117.8                 86.3        0.9728   56.6   41.1
# ...                   ...                  ...           ...    ...    ...
# 1752                111.2                 94.7        0.8640   51.4   46.9
# 1753                117.9                 96.6        0.9081   51.2   49.9
# 1754                122.8                 95.2        0.9488   55.3   48.1
# 1755                117.4                 94.5        0.9238   55.2   44.8
# 1756                117.2                 94.9        0.9192   57.0   47.1
#
#        TOR  TORD   ORB   DRB   FTR  FTRD  Two Pointer Percentage  \
# 0     15.4  18.2  40.7  30.0  32.3  30.4                    53.9
# 1     12.4  15.8  32.1  23.7  36.2  22.4                    54.8
# 2     14.0  19.5  25.5  24.9  30.7  30.0                    54.7
# 3     17.7  22.8  27.4  28.7  32.9  36.6                    52.8
# 4     16.2  17.1  30.0  26.2  39.0  26.9                    56.3
# ...    ...   ...   ...   ...   ...   ...                     ...
# 1752  19.2  15.3  33.9  27.3  32.0  27.6                    52.5
# 1753  17.9  20.1  36.7  30.8  37.1  33.1                    52.9
# 1754  15.8  18.0  31.6  30.2  33.3  34.9                    55.4
# 1755  17.1  15.1  32.1  26.0  34.4  28.1                    54.3
# 1756  16.1  17.4  33.0  23.1  32.1  29.1                    58.2
#
#       Two Point Percentage Allowed  Three Pointer Percentage  \
# 0                             44.6                      32.7
# 1                             44.7                      36.5
# 2                             46.8                      35.2
# 3                             41.9                      36.5
# 4                             40.0                      38.2
# ...                            ...                       ...
# 1752                          45.7                      32.9
# 1753                          49.4                      31.9
# 1754                          44.7                      36.7
# 1755                          44.4                      37.8
# 1756                          44.1                      36.8
#
#       Three Point Percentage Allowed  Posessions Per Game   WAB  YEAR  Target
# 0                               36.2                 71.7   8.6  2016       1
# 1                               37.5                 59.3  11.3  2015       1
# 2                               33.2                 65.9   6.9  2018       1
# 3                               29.7                 67.5   7.0  2019       1
# 4                               29.0                 71.5   7.7  2017       1
# ...                              ...                  ...   ...   ...     ...
# 1752                            32.6                 70.3   1.9  2018       1
# 1753                            33.7                 71.2   7.3  2019       1
# 1754                            35.4                 68.8   9.9  2019       1
# 1755                            30.3                 68.2   2.1  2016       1
# 1756                            35.0                 70.5   4.9  2018       1
#
# [1757 rows x 19 columns]

# %%
tournament.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1757 entries, 0 to 1756
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Offensive Efficency             1757 non-null   float64
#  1   Defensive Efficency             1757 non-null   float64
#  2   Power Rating                    1757 non-null   float64
#  3   EFG_O                           1757 non-null   float64
#  4   EFG_D                           1757 non-null   float64
#  5   TOR                             1757 non-null   float64
#  6   TORD                            1757 non-null   float64
#  7   ORB                             1757 non-null   float64
#  8   DRB                             1757 non-null   float64
#  9   FTR                             1757 non-null   float64
#  10  FTRD                            1757 non-null   float64
#  11  Two Pointer Percentage          1757 non-null   float64
#  12  Two Point Percentage Allowed    1757 non-null   float64
#  13  Three Pointer Percentage        1757 non-null   float64
#  14  Three Point Percentage Allowed  1757 non-null   float64
#  15  Posessions Per Game             1757 non-null   float64
#  16  WAB                             1757 non-null   float64
#  17  YEAR                            1757 non-null   int64
#  18  Target                          1757 non-null   int32
# dtypes: float64(17), int32(1), int64(1)
# memory usage: 254.1 KB

# %%
# Assign X (data) and y (target)

### BEGIN SOLUTION
X = tournament.drop('Target', axis=1)
y = tournament['Target'].values.reshape(-1, 1)
print(X.shape, y.shape)
# Out:
# (1757, 18) (1757, 1)

# %%
# Split the data into training and testing

### BEGIN SOLUTION
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
### END SOLUTION

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScater model and fit it to the training data


X_scaler = StandardScaler().fit(X_train)
# y_scaler = StandardScaler().fit(y_train)

# %%
# Transform the training and testing data using the X_scaler and y_scaler models

### BEGIN SOLUTION
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
# y_train_scaled = y_scaler.transform(y_train)
# y_test_scaled = y_scaler.transform(y_test)
### END SOLUTION

# %%
# Create a LinearRegression model and fit it to the scaled training data

### BEGIN SOLUTION
from sklearn.linear_model import LinearRegression, LogisticRegression
model = LogisticRegression()
model.fit(X_train_scaled, y_train)
### END SOLUTION
# Out:
# C:\Users\foxjc\anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# LogisticRegression()

# %%
# Used X_test_scaled, y_test_scaled, and model.predict(X_test_scaled) to calculate MSE and R2

### BEGIN SOLUTION
from sklearn.metrics import mean_squared_error, accuracy_score, classification_report, plot_confusion_matrix, plot_roc_curve

# MSE = mean_squared_error(y_test_scaled, predictions)
r2 = model.score(X_test_scaled, y_test)
### END SOLUTION

print(f"R2:{r2}")
# Out:
# R2:0.9204545454545454

# %%
classification_report (y_test, predictions)
print(classification_report (y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.91      0.92       221
#            1       0.91      0.93      0.92       219
#
#     accuracy                           0.92       440
#    macro avg       0.92      0.92      0.92       440
# weighted avg       0.92      0.92      0.92       440

# %%
plot_confusion_matrix (model,X_test_scaled, y_test, normalize='true')

# %%
plot_roc_curve (model,X_test_scaled, y_test)

# %%
# LASSO model
# Note: Use an alpha of .01 when creating the model for this activity
from sklearn.linear_model import Lasso

### BEGIN SOLUTION
lasso = Lasso(alpha=.01).fit(X_train_scaled, y_train)

predictions = lasso.predict(X_test)

MSE = mean_squared_error(y_test, predictions)
r2 = lasso.score(X_test_scaled, y_test)
### END SOLUTION

print(f"R2: {r2}")
# Out:
# R2: 0.6092000577984286

# %%
# Ridge model
# Note: Use an alpha of .01 when creating the model for this activity
from sklearn.linear_model import Ridge

### BEGIN SOLUTION
ridge = Ridge(alpha=.01).fit(X_train_scaled, y_train)

predictions = ridge.predict(X_test_scaled)

MSE = mean_squared_error(y_test, predictions)
r2 = ridge.score(X_test_scaled, y_test)
### END SOLUTION

print(f"R2: {r2}")
# Out:
# R2: 0.6582143897027075

# %%
# ElasticNet model
# Note: Use an alpha of .01 when creating the model for this activity
from sklearn.linear_model import ElasticNet

### BEGIN SOLUTION
elasticnet = ElasticNet(alpha=.01).fit(X_train_scaled, y_train)

predictions = elasticnet.predict(X_test)

MSE = mean_squared_error(y_test, predictions)
r2 = elasticnet.score(X_test_scaled, y_test)
### END SOLUTION

print(f"R2: {r2}")
# Out:
# R2: 0.6291915765257594

# %%
model.score(X_test_scaled, y_test)
# Out:
# 0.9204545454545454
