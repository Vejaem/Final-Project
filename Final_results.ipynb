# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
#read in csv file, utitilizing read.csv method
results_df = pd.read_csv("results.csv")
results_df.dropna(axis=1)
results_df
# Out:
#         Overall         2019         2018         2017         2016  \
# 0       Overall  2019.000000  2018.000000  2017.000000  2016.000000
# 1   0.879545455     0.898876     0.886364     0.920455     0.852273
# 2   0.886363636     0.842697     0.818182     0.897727     0.863636
# 3   0.859090909     0.898876     0.886364     0.909091     0.818182
# 4   0.863636364     0.898876     0.875000     0.863636     0.875000
# 5   0.822727273     0.786517     0.818182     0.795455     0.818182
# 6         0.825     0.853933     0.818182     0.784091     0.829545
# 7   0.809090909     0.786517     0.818182     0.784091     0.795455
# 8   0.815909091     0.786517     0.784091     0.784091     0.784091
# 9   0.822727273     0.786517     0.784091     0.784091     0.784091
# 10  0.815909091     0.786517     0.784091     0.784091     0.784091
# 11  0.815909091     0.786517     0.784091     0.784091     0.784091
# 12  0.815909091     0.786517     0.784091     0.784091     0.784091
# ...

# %%
new_results_df= results_df.drop(columns=['Unnamed: 7'])
new_results_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-dcc4a6439f31> in <module>
# ----> 1 new_results_df= results_df.drop(columns=['Unnamed: 7'])
#       2 new_results_df
#
# ~\Anaconda3\envs\Machine Learning\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4310             level=level,
#    4311             inplace=inplace,
# -> 4312             errors=errors,
#    4313         )
#    4314
#
# ~\Anaconda3\envs\Machine Learning\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ...

# %%
indexed_df = new_results_df.set_index('Unnamed: 0')
indexed_df

# %%
indexed_df.columns = ['Overall','2019', '2018', '2017', '2016', '2015']
indexed_df.head()

# %%
indexed_df.to_csv('results2.csv', index=False)
