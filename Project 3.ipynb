# %%
# Dependencies
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
#read in csv file, utitilizing read.csv method
cbb_df = pd.read_csv("cbb.csv")
cbb_df
# Out:
#                 TEAM CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  \
# 0     North Carolina  ACC  40  33  123.3   94.9   0.9531   52.6   48.1  15.4
# 1          Wisconsin  B10  40  36  129.1   93.6   0.9758   54.8   47.7  12.4
# 2           Michigan  B10  40  33  114.4   90.4   0.9375   53.9   47.7  14.0
# 3         Texas Tech  B12  38  31  115.2   85.2   0.9696   53.5   43.0  17.7
# 4            Gonzaga  WCC  39  37  117.8   86.3   0.9728   56.6   41.1  16.2
# ...              ...  ...  ..  ..    ...    ...      ...    ...    ...   ...
# 1752       Texas A&M  SEC  35  22  111.2   94.7   0.8640   51.4   46.9  19.2
# 1753             LSU  SEC  35  28  117.9   96.6   0.9081   51.2   49.9  17.9
# 1754       Tennessee  SEC  36  31  122.8   95.2   0.9488   55.3   48.1  15.8
# 1755         Gonzaga  WCC  35  27  117.4   94.5   0.9238   55.2   44.8  17.1
# 1756         Gonzaga  WCC  37  32  117.2   94.9   0.9192   57.0   47.1  16.1
#
# ...

# %%
#filtering down to one year of data, using dot notation and a conditional statement "2019"
cbb_df = cbb_df[cbb_df.YEAR == 2019]
cbb_df
# Out:
#             TEAM  CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  \
# 3     Texas Tech   B12  38  31  115.2   85.2   0.9696   53.5   43.0  17.7
# 6       Virginia   ACC  38  35  123.0   89.9   0.9736   55.2   44.7  14.7
# 16          Duke   ACC  38  32  118.9   89.2   0.9646   53.6   45.0  17.5
# 17        Purdue   B10  36  26  122.8   94.3   0.9539   53.6   49.0  15.8
# 27      Kentucky   SEC  37  30  117.5   89.8   0.9568   53.0   46.6  18.6
# ...          ...   ...  ..  ..    ...    ...      ...    ...    ...   ...
# 1726     Houston  Amer  37  33  115.7   90.5   0.9439   52.1   42.5  16.5
# 1734    Michigan   B10  37  30  114.6   85.6   0.9665   51.6   44.1  13.9
# 1749      Oregon   P12  38  25  108.1   91.7   0.8687   52.0   46.4  17.8
# 1753         LSU   SEC  35  28  117.9   96.6   0.9081   51.2   49.9  17.9
# 1754   Tennessee   SEC  36  31  122.8   95.2   0.9488   55.3   48.1  15.8
#
#       ...  FTRD  TWO_P_O  TWO_P_D  THREE_P_O  THREE_P_D  ADJ_T   WAB  \
# ...

# %%
# duplicate postseason column to later use as binary option
cbb_df['POSTSEASON_BINARY'] = cbb_df['POSTSEASON']
cbb_df.head()
# Out:
# C:\Users\brend\Anaconda3\envs\Machine Learning\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           TEAM CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  ...  \
# 3   Texas Tech  B12  38  31  115.2   85.2   0.9696   53.5   43.0  17.7  ...
# 6     Virginia  ACC  38  35  123.0   89.9   0.9736   55.2   44.7  14.7  ...
# 16        Duke  ACC  38  32  118.9   89.2   0.9646   53.6   45.0  17.5  ...
# 17      Purdue  B10  36  26  122.8   94.3   0.9539   53.6   49.0  15.8  ...
# 27    Kentucky  SEC  37  30  117.5   89.8   0.9568   53.0   46.6  18.6  ...
#
#     TWO_P_O  TWO_P_D  THREE_P_O  THREE_P_D  ADJ_T   WAB  POSTSEASON  SEED  \
# ...

# %%
cbb_df['POSTSEASON_BINARY'] = cbb_df['POSTSEASON']
cbb_df.POSTSEASON_BINARY[cbb_df.POSTSEASON_BINARY == "NA"] = 0
cbb_df.POSTSEASON_BINARY[cbb_df.POSTSEASON_BINARY != 0] = 1
cbb_df.head(10)
# Out:
# C:\Users\brend\Anaconda3\envs\Machine Learning\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\brend\Anaconda3\envs\Machine Learning\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\brend\Anaconda3\envs\Machine Learning\lib\site-packages\pandas\core\series.py:963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
cbb_df = pd.DataFrame(np.random.randn(1000, 4), columns=['BARTHAG','W','POSTSEASON_BINARY','WAB'])
pd.plotting.scatter_matrix(cbb_df, alpha=0.2)
# Out:
# array([[<AxesSubplot:xlabel='BARTHAG', ylabel='BARTHAG'>,
#         <AxesSubplot:xlabel='W', ylabel='BARTHAG'>,
#         <AxesSubplot:xlabel='POSTSEASON_BINARY', ylabel='BARTHAG'>,
#         <AxesSubplot:xlabel='WAB', ylabel='BARTHAG'>],
#        [<AxesSubplot:xlabel='BARTHAG', ylabel='W'>,
#         <AxesSubplot:xlabel='W', ylabel='W'>,
#         <AxesSubplot:xlabel='POSTSEASON_BINARY', ylabel='W'>,
#         <AxesSubplot:xlabel='WAB', ylabel='W'>],
#        [<AxesSubplot:xlabel='BARTHAG', ylabel='POSTSEASON_BINARY'>,
#         <AxesSubplot:xlabel='W', ylabel='POSTSEASON_BINARY'>,
#         <AxesSubplot:xlabel='POSTSEASON_BINARY', ylabel='POSTSEASON_BINARY'>,
#         <AxesSubplot:xlabel='WAB', ylabel='POSTSEASON_BINARY'>],
#        [<AxesSubplot:xlabel='BARTHAG', ylabel='WAB'>,
#         <AxesSubplot:xlabel='W', ylabel='WAB'>,
#         <AxesSubplot:xlabel='POSTSEASON_BINARY', ylabel='WAB'>,
#         <AxesSubplot:xlabel='WAB', ylabel='WAB'>]], dtype=object)

# %%
plt.savefig('scatter_matrix.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-0e985c37b352> in <module>
# ----> 1 plt.savefig('scatter_matrix.png')
#
# AttributeError: module 'matplotlib' has no attribute 'savefig'

# %%
cbb_df = pd.DataFrame(np.random.randn(1000, 4), columns=['W','ADJOE','ADJDE','BARTHAG'])
pd.plotting.scatter_matrix(cbb_df, alpha=0.2)
# Out:
# array([[<AxesSubplot:xlabel='W', ylabel='W'>,
#         <AxesSubplot:xlabel='ADJOE', ylabel='W'>,
#         <AxesSubplot:xlabel='ADJDE', ylabel='W'>,
#         <AxesSubplot:xlabel='BARTHAG', ylabel='W'>],
#        [<AxesSubplot:xlabel='W', ylabel='ADJOE'>,
#         <AxesSubplot:xlabel='ADJOE', ylabel='ADJOE'>,
#         <AxesSubplot:xlabel='ADJDE', ylabel='ADJOE'>,
#         <AxesSubplot:xlabel='BARTHAG', ylabel='ADJOE'>],
#        [<AxesSubplot:xlabel='W', ylabel='ADJDE'>,
#         <AxesSubplot:xlabel='ADJOE', ylabel='ADJDE'>,
#         <AxesSubplot:xlabel='ADJDE', ylabel='ADJDE'>,
#         <AxesSubplot:xlabel='BARTHAG', ylabel='ADJDE'>],
#        [<AxesSubplot:xlabel='W', ylabel='BARTHAG'>,
#         <AxesSubplot:xlabel='ADJOE', ylabel='BARTHAG'>,
#         <AxesSubplot:xlabel='ADJDE', ylabel='BARTHAG'>,
#         <AxesSubplot:xlabel='BARTHAG', ylabel='BARTHAG'>]], dtype=object)

# %%
cbb_df = pd.DataFrame(np.random.randn(1000, 4), columns=['ADJOE','EFG_O','ORB','W'])
pd.plotting.scatter_matrix(cbb_df, alpha=0.2)
# Out:
# array([[<AxesSubplot:xlabel='ADJOE', ylabel='ADJOE'>,
#         <AxesSubplot:xlabel='EFG_O', ylabel='ADJOE'>,
#         <AxesSubplot:xlabel='ORB', ylabel='ADJOE'>,
#         <AxesSubplot:xlabel='W', ylabel='ADJOE'>],
#        [<AxesSubplot:xlabel='ADJOE', ylabel='EFG_O'>,
#         <AxesSubplot:xlabel='EFG_O', ylabel='EFG_O'>,
#         <AxesSubplot:xlabel='ORB', ylabel='EFG_O'>,
#         <AxesSubplot:xlabel='W', ylabel='EFG_O'>],
#        [<AxesSubplot:xlabel='ADJOE', ylabel='ORB'>,
#         <AxesSubplot:xlabel='EFG_O', ylabel='ORB'>,
#         <AxesSubplot:xlabel='ORB', ylabel='ORB'>,
#         <AxesSubplot:xlabel='W', ylabel='ORB'>],
#        [<AxesSubplot:xlabel='ADJOE', ylabel='W'>,
#         <AxesSubplot:xlabel='EFG_O', ylabel='W'>,
#         <AxesSubplot:xlabel='ORB', ylabel='W'>,
#         <AxesSubplot:xlabel='W', ylabel='W'>]], dtype=object)

# %%
cbb_df = pd.DataFrame(np.random.randn(1000, 4), columns=['ADJDE','EFG_D','DRB','W'])
pd.plotting.scatter_matrix(cbb_df, alpha=0.2)
# Out:
# array([[<AxesSubplot:xlabel='ADJDE', ylabel='ADJDE'>,
#         <AxesSubplot:xlabel='EFG_D', ylabel='ADJDE'>,
#         <AxesSubplot:xlabel='DRB', ylabel='ADJDE'>,
#         <AxesSubplot:xlabel='W', ylabel='ADJDE'>],
#        [<AxesSubplot:xlabel='ADJDE', ylabel='EFG_D'>,
#         <AxesSubplot:xlabel='EFG_D', ylabel='EFG_D'>,
#         <AxesSubplot:xlabel='DRB', ylabel='EFG_D'>,
#         <AxesSubplot:xlabel='W', ylabel='EFG_D'>],
#        [<AxesSubplot:xlabel='ADJDE', ylabel='DRB'>,
#         <AxesSubplot:xlabel='EFG_D', ylabel='DRB'>,
#         <AxesSubplot:xlabel='DRB', ylabel='DRB'>,
#         <AxesSubplot:xlabel='W', ylabel='DRB'>],
#        [<AxesSubplot:xlabel='ADJDE', ylabel='W'>,
#         <AxesSubplot:xlabel='EFG_D', ylabel='W'>,
#         <AxesSubplot:xlabel='DRB', ylabel='W'>,
#         <AxesSubplot:xlabel='W', ylabel='W'>]], dtype=object)

# %%
cbb_df = pd.DataFrame(np.random.randn(1000, 4), columns=['ADJDE','EFG_D','DRB','W'])
pd.plotting.scatter_matrix(cbb_df, alpha=0.2)
# Out:
# array([[<AxesSubplot:xlabel='ADJDE', ylabel='ADJDE'>,
#         <AxesSubplot:xlabel='EFG_D', ylabel='ADJDE'>,
#         <AxesSubplot:xlabel='DRB', ylabel='ADJDE'>,
#         <AxesSubplot:xlabel='W', ylabel='ADJDE'>],
#        [<AxesSubplot:xlabel='ADJDE', ylabel='EFG_D'>,
#         <AxesSubplot:xlabel='EFG_D', ylabel='EFG_D'>,
#         <AxesSubplot:xlabel='DRB', ylabel='EFG_D'>,
#         <AxesSubplot:xlabel='W', ylabel='EFG_D'>],
#        [<AxesSubplot:xlabel='ADJDE', ylabel='DRB'>,
#         <AxesSubplot:xlabel='EFG_D', ylabel='DRB'>,
#         <AxesSubplot:xlabel='DRB', ylabel='DRB'>,
#         <AxesSubplot:xlabel='W', ylabel='DRB'>],
#        [<AxesSubplot:xlabel='ADJDE', ylabel='W'>,
#         <AxesSubplot:xlabel='EFG_D', ylabel='W'>,
#         <AxesSubplot:xlabel='DRB', ylabel='W'>,
#         <AxesSubplot:xlabel='W', ylabel='W'>]], dtype=object)
